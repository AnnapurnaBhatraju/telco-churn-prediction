# %% [markdown]
# ## Step 1. Importing Required Libraries
#
# We begin by importing essential Python libraries that will be used throughout the project.
# - pandas – for data manipulation and analysis

# %%
import pandas as pd

# %% [markdown]
# ## Step 2. Loading the Telco Churn Dataset
#
# We'll load the dataset into a pandas DataFrame for further exploration and analysis.

# %%
df = pd.read_csv('Dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# ## Step 3. Exploratory Data Analysis (EDA) – Basic Overview
#
# In this section, we will explore the dataset to understand its structure and content. The following steps will be performed:
#
# - Dataset shape
# - Display top and bottom records (head and tail)
# - Data types of each column
# - Check for missing values
# - Basic statistical summary using describe()

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.describe(include = ['object'])
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.describe(include = ['number'])
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ## Step 4: Data Cleaning
#
# After completing basic EDA, we observed issues that must be resolved before proceeding to data visualization and modeling. In this step, we will:
#
# - Convert the `TotalCharges` column to numeric format (it's currently an object).
# - Handle missing or invalid values resulting from the conversion.
# - Review and clean other relevant inconsistencies to ensure the dataset is analysis-ready.

# %% [markdown]
# ### Conversion of `TotalCharges` to Numeric
#
# The `TotalCharges` column was stored as an object due to the presence of invalid characters (blank strings). We used `pd.to_numeric()` with `errors='coerce'` to convert valid entries to float and replace invalid ones with NaN.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors = 'coerce')

# %% [markdown]
# ### Identifying Missing Values
#
# We check how many entries in `TotalCharges` became NaN after the conversion. These are rows with missing or blank values, which must be addressed.

# %%
missing_totalcharges = df['TotalCharges'].isna().sum()
print(f"Missing values in 'TotalCharges' after conversion: {missing_totalcharges}")
# Out:
# Missing values in 'TotalCharges' after conversion: 11

# %% [markdown]
# ### Dropping Rows with Missing `TotalCharges`
#
# Since only a small number of rows have missing values in `TotalCharges`, we chose to drop them to maintain dataset integrity. Now, the dataset is free of critical missing values and ready for visualization.

# %%
df.dropna(subset = ['TotalCharges'], inplace = True)

# %%
# Confirm removal
print(f"Dataset shape after dropping rows with missing TotalCharges: {df.shape}")
# Out:
# Dataset shape after dropping rows with missing TotalCharges: (7032, 21)

# %% [markdown]
# ### Final Dataset Check
#
# We confirmed that there are no more missing values and all columns have appropriate data types. The dataset is now clean and ready for univariate and bivariate analysis.

# %%
# Final check for missing values in the dataset
print("Missing values in dataset:\n")
print(df.isnull().sum())
# Out:
# Missing values in dataset:
#
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Check datatypes after cleaning
print("\nData types after cleaning:\n")
print(df.dtypes)
# Out:
# Data types after cleaning:
#
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object
